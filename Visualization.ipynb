# %% [markdown]
# <a href="https://colab.research.google.com/github/am9433859-dotcom/Student-performance/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Built in dataset
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#'iris','tips',

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.sample(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 108       18.24  3.76    Male     No   Sat  Dinner     2
# 60        20.29  3.21    Male    Yes   Sat  Dinner     2
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 83        32.68  5.00    Male    Yes  Thur   Lunch     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 45        18.29  3.00    Male     No   Sun  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 94        22.75  3.25  Female     No   Fri  Dinner     2
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# ...

# %%
iris = sns.load_dataset('iris')

# %%
iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 114           5.8          2.8           5.1          2.4   virginica
# 124           6.7          3.3           5.7          2.1   virginica
# 117           7.7          3.8           6.7          2.2   virginica
# 51            6.4          3.2           4.5          1.5  versicolor
# 115           6.4          3.2           5.3          2.3   virginica
# 110           6.5          3.2           5.1          2.0   virginica
# 96            5.7          2.9           4.2          1.3  versicolor
# 130           7.4          2.8           6.1          1.9   virginica
# 28            5.2          3.4           1.4          0.2      setosa
# 129           7.2          3.0           5.8          1.6   virginica

# %%
sns.scatterplot(data=tips, x='total_bill',y='tip',hue='sex')
plt.title("Scatter Plot: Total Bill vs Tip")
plt.show()

# %%
sns.swarmplot(data=tips, x='total_bill',y='tip',hue='sex')
plt.title("Swarm Plot: Total Bill vs Tip")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=tips, x='day',y='total_bill',hue='sex')
plt.title("Swarm Plot: Total Bill vs Tip")
plt.show()

# %%
sns.scatterplot(data=tips, x='day',y='total_bill',hue='sex')
plt.title("Scatter Plot: Total Bill vs Tip")
plt.show()

# %%
sns.stripplot(data=tips, x='day',y='total_bill',hue='sex')
plt.title("Strip Plot: Total Bill vs Tip")
plt.show()

# %%
sns.boxplot(data=tips, x='day', y='total_bill', hue='sex')
plt.title("Box Plot: Total Bill by Day and Gender")
plt.show()

# %%
sns.boxplot(data=tips, x='day', y='tip', hue='sex')
plt.title("Box Plot: Total Bill by Day and Gender")
plt.show()

# %%
## Violin Plot
sns.violinplot(data=tips, x='day', y='tip', hue='sex')
plt.title("violin Plot: Total Bill by Day and Gender")
plt.show()

# %%
sns.catplot(data=tips, x='day', y='tip', hue='sex',kind='box')
plt.title("category Plot: Total Bill by Day and Gender")
plt.show()

# %%
sns.barplot(data=tips, x='sex', y='total_bill', hue='smoker', color='green')
plt.title("Bar Plot: Total Bill by Day and Gender")
plt.show()
# Out:
# /tmp/ipython-input-876075443.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:green'` for the same effect.
#
#   sns.barplot(data=tips, x='sex', y='total_bill', hue='smoker', color='green')

# %%
import numpy as np
sns.barplot(data=tips, x='sex', y='total_bill', hue='smoker', color='yellow',estimator = np.max)
plt.title("Bar Plot: Total Bill by Day and Gender")
plt.show()
# Out:
# /tmp/ipython-input-2832427276.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:yellow'` for the same effect.
#
#   sns.barplot(data=tips, x='sex', y='total_bill', hue='smoker', color='yellow',estimator = np.max)

# %%
sns.pointplot(data=tips, x='sex',y='total_bill',hue='smoker',dodge=True)
plt.title('point plot')
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(data=tips, x='day',hue='sex')
plt.title(' plotcount : Day ')
plt.show()

# %%
sns.countplot(data=tips, x='day')
plt.title(' plotcount : Day ')
plt.show()

# %%
sns.lineplot(data=tips, x='day',y='total_bill')
plt.title(' lineplot : Day vs total bill ')
plt.show()

# %%
sns.lineplot(data=tips, x='day',y='tip',hue='sex')
plt.title(' lineplot : Day vs total bill ')
plt.show()

# %%
# Regression plot
sns.regplot(data=tips, x='tip',y='total_bill', color='green')
plt.title(' lineplot : Day vs total bill ')
plt.show()

# %%
sns.regplot(data=tips, x='tip',y='total_bill',ci=0, color='green')
plt.title(' lineplot : Day vs total bill ')
plt.show()

# %%
sns.lmplot(data=tips, x='tip',y='total_bill',ci=0, hue = 'sex')
plt.title(' lineplot : Day vs total bill ')
plt.show()

# %%
sns.lmplot(data=tips, x='size',y='total_bill', hue = 'sex')
plt.title(' lineplot : Day vs total bill ')
plt.show()

# %%
sns.residplot(data=tips, x='size',y='total_bill', color='red')
plt.title(' lineplot : Day vs total bill ')
plt.show()

# %%
sns.lmplot(data=iris, x='sepal_length',y='petal_length', hue = 'species')
plt.title(' lineplot :sepal_length vs petal_length ')
plt.show()

# %%
bills = [10,15,20,25,30]

# %%
sns.histplot(data=tips, x='total_bill', kde =True)
plt.title(' hisplot :Distribution of total bills')
plt.show()

# %%
sns.kdeplot(data=tips, x='total_bill', fill = True,color = 'green',hue='sex')
plt.title(' KDEplot :KDE plot of Total BIll')
plt.show()

# %%
sns.kdeplot(data=tips, x='total_bill', fill = True,color='red')
plt.title(' KDEplot :KDE plot of Total BIll')
plt.show()

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex', fill=True, palette={'Male': 'green', 'Female': 'red'}))
plt.title("KDE Plot of Total Bill by Gender")
plt.show()

# %%
sns.kdeplot(data=iris, x='petal_length', fill=True, hue='species', palette={'setosa': 'green', 'versicolor': 'red','virginica':'brown'})
plt.title("Distribution of Total Bill")
plt.show()

# %%
sns.displot(data=tips, x='total_bill',bins=10,kde=True,col='sex')
plt.title('Distribution Plot of Sepal Length by Species',loc:'right')
plt.show()
# Out:
#   File "/tmp/ipython-input-2823329587.py", line 2
#     plt.title('Distribution Plot of Sepal Length by Species',loc:'right')
#                                                                 ^
# SyntaxError: invalid syntax

# %%
sns.displot(data=iris, x='sepal_length', kde=True, col='species')
plt.title("Distribution Plot of Sepal Length by Species",loc='right', y=1.1)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
g = sns.displot(data=iris, x='sepal_length', kde=True, col='species')
g.fig.suptitle("Distribution Plot of Sepal Length by Species", ha='center')
g.fig.subplots_adjust(top=0.85)
plt.show()

# %%
g = sns.displot(data=iris, x='sepal_length', kde=True, col='species')
g.fig.suptitle("Distribution Plot of Sepal Length by Species", ha='center')
g.fig.subplots_adjust(top=0.85)
plt.show()

# %%
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Numeric Columns")
plt.show()

# %%
corr = iris.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Numeric Columns")
plt.show()

# %%
# Shows relationship between two variables (line/scatter) # Create multiple subplots using hue, col, or row
sns.relplot(data=tips, x='total_bill', y='tip', col='sex', hue='smoker', size='size')
plt.title("Relationship Between Total Bill and Tip", loc='right', y=1.1)
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Shows relationship between two variables (line/scatter) # Create multiple subplots using hue, col, or row
sns.relplot(data=iris, x='petal_length', y='sepal_length', col='species', hue='species', size=5)
plt.title("Relationship Between Total Bill and Tip", loc='right', y=1.1)
plt.show()

# %%
iris.sample
# Out:
# <bound method NDFrame.sample of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>
